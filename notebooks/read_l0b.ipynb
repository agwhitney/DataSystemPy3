# %%
import matplotlib.pyplot as plt
from processL0b.reader import Reader

# %%
# Plot channel against time - found 24 QH to be the one that freezes out

# readers = [
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data412/l0b/26_04_12__07_48_26__cristalANT.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data412/l0b/26_04_12__08_12_04__cristalANT.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data412/l0b/26_04_12__08_21_35__cristalANT.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data408/l0b/26_04_08__05_30_45__cristal.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data413/l0b/26_04_13__10_27_09__debugANT.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data413/l0b/26_04_13__10_34_29__debugANT.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data413/l0b/26_04_13__12_59_35__cristalANT.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data413/l0b/26_04_13__13_25_54__cristalANT.h5"),
#     # Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data413/l0b/26_04_13__13_29_44__cristalANT.h5"),
#     Reader(filename="C:/Users/adamgw/Desktop/CRISTAL_AMR/data414/l0b/26_04_14__08_29_52__cristalANT.h5"),
# ]

for reader in readers:
    channel = reader.radiometer.channels[7]  # 24 QH determined as the one freezing out
    labels = [channel.label for channel in reader.radiometer.channels]
    index = list(range(1, 41))  # "AMR-(ch18/ch24)-external QH"
    fig, ax = plt.subplots(2, 1)

    t_rad = (reader.radiometer.data['Timestamp'] - reader.radiometer.data['Timestamp'][0])
    counts = reader.radiometer.data[channel.label]
    ax[0].plot(t_rad, reader.radiometer.data[labels])

    t_thm = (reader.thermistors.data['Timestamp'] - reader.thermistors.data['Timestamp'][0])
    temps = reader.thermistors.data
    ax[1].plot(t_thm, temps[index])

    ax[0].set(title=f"{channel.label} - {reader.time}", ylabel="Counts", xlim=[1200, 1600])
    ax[1].set(xlabel="Time (s)", ylabel="Temperature (K)", xlim=[1200, 1600])
    plt.show()
